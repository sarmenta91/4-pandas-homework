# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# Read purchasing file and store into pandas data frame
purchase_data = pd.read_csv('Resources/purchase_data.csv')
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#total number of players
totalplayers = len(purchase_data["SN"].unique())
totalplayers
# Out:
# 576

# %%
#Run basic calculations to obtain number of unique items, average price,number of purchases,total revenue

#unique items
uniqueitems = len(purchase_data["Item ID"].unique())
uniqueitems
# Out:
# 183

# %%
#number of purchases
numberpurchases = len(purchase_data["Purchase ID"].unique())
numberpurchases
# Out:
# 780

# %%
#Total Revenue
totalrevenue = purchase_data["Price"].sum()
totalrevenue
# Out:
# 2379.77

# %%
#Average Price
averageprice = purchase_data["Price"].mean()
averageprice
# Out:
# 3.050987179487176

# %%
#summary table
summarytable = pd.DataFrame({"Unique Item": [uniqueitems],
                            "Number of Purchases": [numberpurchases],
                            "Average Price": [averageprice],
                            "Total Revenue": [totalrevenue]})
summarytable.head()

summarytable.style.format({"Average Price": "${:.2f}", "Total Revenue": "${:.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_b4affb28_a0b4_11e8_8901_144f8ae6cb7e" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Unique Item</th>
#         <th class="col_heading level0 col1" >Number of Purchases</th>
#         <th class="col_heading level0 col2" >Average Price</th>
#         <th class="col_heading level0 col3" >Total Revenue</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b4affb28_a0b4_11e8_8901_144f8ae6cb7elevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_b4affb28_a0b4_11e8_8901_144f8ae6cb7erow0_col0" class="data row0 col0" >183</td>
#         <td id="T_b4affb28_a0b4_11e8_8901_144f8ae6cb7erow0_col1" class="data row0 col1" >780</td>
#         <td id="T_b4affb28_a0b4_11e8_8901_144f8ae6cb7erow0_col2" class="data row0 col2" >$3.05</td>
#         <td id="T_b4affb28_a0b4_11e8_8901_144f8ae6cb7erow0_col3" class="data row0 col3" >$2379.77</td>
#     </tr></tbody>
# </table>

# %%
#Percentage and Count of Male Players
#Percentage and Count of Female Players
#Percentage and Count of Other / Non-Disclosed

allcount = purchase_data["SN"].count()
allcount
# Out:
# 780

# %%
#male data
malecount = purchase_data[purchase_data["Gender"] == "Male"]["SN"].count()
malecount
# Out:
# 652

# %%
#percentmale
percentmale = malecount / totalplayers * 100
percentmale = percentmale.round(2)
percentmale
# Out:
# 113.19

# %%
#female count
femalecount = purchase_data[purchase_data["Gender"] == "Female"]["SN"].count()
femalecount
# Out:
# 113

# %%
#percentfemale
femalepercent = femalecount / totalplayers * 100
femalepercent = femalepercent.round(2)
femalepercent.round(2)
femalepercent
# Out:
# 19.62

# %%
othercount = allcount - femalecount - malecount
othercount
# Out:
# 15

# %%
otherpercent = othercount / totalplayers * 100
otherpercent.round(2)
otherpercent
#Now create the dataframe table

gendertable = pd.DataFrame({"Gender": ["Male", "Female", "Other / Non-Disclosed"], "Percentage of Players": 
                            [percentmale, femalepercent, otherpercent],
                                        "Total Count": [malecount, femalecount, othercount]}, columns = 
                                        ["Gender", "Percentage of Players", "Total Count"])
                                        


gendertable.style.format({"Percentage of Players": "{:.2f}%"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7e" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Gender</th>
#         <th class="col_heading level0 col1" >Percentage of Players</th>
#         <th class="col_heading level0 col2" >Total Count</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7elevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow0_col0" class="data row0 col0" >Male</td>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow0_col1" class="data row0 col1" >113.19%</td>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow0_col2" class="data row0 col2" >652</td>
#     </tr>    <tr>
#         <th id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7elevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow1_col0" class="data row1 col0" >Female</td>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow1_col1" class="data row1 col1" >19.62%</td>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow1_col2" class="data row1 col2" >113</td>
#     </tr>    <tr>
#         <th id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7elevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow2_col0" class="data row2 col0" >Other / Non-Disclosed</td>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow2_col1" class="data row2 col1" >2.60%</td>
#         <td id="T_1c9009c8_a0b5_11e8_a595_144f8ae6cb7erow2_col2" class="data row2 col2" >15</td>
#     </tr></tbody>
# </table>

# %%
#Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#Create a summary data frame to hold the results
#Sort the total purchase value column in descending order
#Display the summary data frame

#figure out the math
genderpurchasetotal = purchase_data.groupby(["Gender"]).sum()["Price"]
genderpurchasetotal = genderpurchasetotal.round(2)
genderpurchasetotal
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
genderaverage = purchase_data.groupby(["Gender"]).mean()["Price"]
genderaverage = genderaverage.round(2)
genderaverage
# Out:
# Gender
# Female                   3.20
# Male                     3.02
# Other / Non-Disclosed    3.35
# Name: Price, dtype: float64

# %%
gendercounts = purchase_data.groupby(["Gender"]).count()["Price"]
gendercounts
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Price, dtype: int64

# %%
perperson = genderpurchasetotal / gendercounts 
perperson =perperson.round(2)
perperson
# Out:
# Gender
# Female                   3.20
# Male                     3.02
# Other / Non-Disclosed    3.35
# Name: Price, dtype: float64

# %%
#create the table
genderpurchasetable = pd.DataFrame({"Purchase Count": gendercounts, 
                                   "Average Purchase Price": genderaverage, "Total Purchase Value": genderpurchasetotal,
                                   "Avg Purchase Total Per Person": perperson})

# %%
genderpurchasetable
genderpurchasetable.style.format({"Average Purchase Price": "${:.2f}", "Avg Purchase Total Per Person": "${:.2f}",
                                 "Total Purchase Value": "${:.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7e" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Average Purchase Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#         <th class="col_heading level0 col3" >Avg Purchase Total Per Person</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Gender</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7elevel0_row0" class="row_heading level0 row0" >Female</th>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow0_col0" class="data row0 col0" >113</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow0_col1" class="data row0 col1" >$3.20</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow0_col2" class="data row0 col2" >$361.94</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow0_col3" class="data row0 col3" >$3.20</td>
#     </tr>    <tr>
#         <th id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7elevel0_row1" class="row_heading level0 row1" >Male</th>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow1_col0" class="data row1 col0" >652</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow1_col1" class="data row1 col1" >$3.02</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow1_col2" class="data row1 col2" >$1967.64</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow1_col3" class="data row1 col3" >$3.02</td>
#     </tr>    <tr>
#         <th id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7elevel0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow2_col0" class="data row2 col0" >15</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow2_col1" class="data row2 col1" >$3.35</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow2_col2" class="data row2 col2" >$50.19</td>
#         <td id="T_cef29cb6_a0b5_11e8_af42_144f8ae6cb7erow2_col3" class="data row2 col3" >$3.35</td>
#     </tr></tbody>
# </table>

# %%
#Establish bins for ages
#Categorize the existing players using the age bins. Hint: use pd.cut()
#Calculate the numbers and percentages by age group
#Create a summary data frame to hold the results
#Optional: round the percentage column to two decimal points
#Display Age Demographics Table

#binning

age_bins = [0, 9.90, 14.90, 19.90, 24.9, 29.9, 34.90, 39.90, 9999999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", ">40"]

# %%
playerdemographic = pd.cut(purchase_data["Age"], age_bins, labels=group_names)
playerdemographic
# Out:
# 0      20-24
# 1        >40
# 2      20-24
# 3      20-24
# 4      20-24
# 5      20-24
# 6      35-39
# 7      20-24
# 8      20-24
# 9      35-39
# 10     20-24
# 11     20-24
# 12     20-24
# 13     20-24
# 14     35-39
# 15     20-24
# 16     20-24
# 17     20-24
# 18     20-24
# 19     30-34
# 20     20-24
# 21     20-24
# 22     35-39
# 23       >40
# 24     30-34
# 25     25-29
# 26     10-14
# 27       <10
# 28     20-24
# 29     20-24
#        ...
# 750    20-24
# 751    10-14
# 752    15-19
# 753    35-39
# 754    20-24
# 755    10-14
# 756    20-24
# 757    15-19
# 758    20-24
# 759    25-29
# 760    20-24
# 761      >40
# 762    25-29
# 763    20-24
# 764    15-19
# 765    15-19
# 766    20-24
# 767      <10
# 768    35-39
# 769    15-19
# 770    30-34
# 771    15-19
# 772    25-29
# 773    20-24
# 774    10-14
# 775    20-24
# 776    20-24
# 777    20-24
# 778      <10
# 779    20-24
# Name: Age, Length: 780, dtype: category
# Categories (8, object): [<10 < 10-14 < 15-19 < 20-24 < 25-29 < 30-34 < 35-39 < >40]

# %%
#calculations
agedemocount =playerdemographic.value_counts()
agedemocount = agedemocount.round(2)

agepercent = agedemocount / totalplayers *100
agepercent =agepercent.round(2)
agepercent
# Out:
# 20-24    63.37
# 15-19    23.61
# 25-29    17.53
# 30-34    12.67
# 35-39     7.12
# 10-14     4.86
# <10       3.99
# >40       2.26
# Name: Age, dtype: float64

# %%
#create table
agedemotable = pd.DataFrame({"Total Count": agedemocount, "Percentage of Players": agepercent})


agedemotable = agedemotable.sort_index()
agedemotable

agedemotable.style.format({"Percentage of Players": "{:.2f}%"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7e" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Total Count</th>
#         <th class="col_heading level0 col1" >Percentage of Players</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row0" class="row_heading level0 row0" ><10</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow0_col0" class="data row0 col0" >23</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow0_col1" class="data row0 col1" >3.99%</td>
#     </tr>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row1" class="row_heading level0 row1" >10-14</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow1_col0" class="data row1 col0" >28</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow1_col1" class="data row1 col1" >4.86%</td>
#     </tr>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row2" class="row_heading level0 row2" >15-19</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow2_col0" class="data row2 col0" >136</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow2_col1" class="data row2 col1" >23.61%</td>
#     </tr>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row3" class="row_heading level0 row3" >20-24</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow3_col0" class="data row3 col0" >365</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow3_col1" class="data row3 col1" >63.37%</td>
#     </tr>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row4" class="row_heading level0 row4" >25-29</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow4_col0" class="data row4 col0" >101</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow4_col1" class="data row4 col1" >17.53%</td>
#     </tr>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row5" class="row_heading level0 row5" >30-34</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow5_col0" class="data row5 col0" >73</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow5_col1" class="data row5 col1" >12.67%</td>
#     </tr>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row6" class="row_heading level0 row6" >35-39</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow6_col0" class="data row6 col0" >41</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow6_col1" class="data row6 col1" >7.12%</td>
#     </tr>    <tr>
#         <th id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7elevel0_row7" class="row_heading level0 row7" >>40</th>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow7_col0" class="data row7 col0" >13</td>
#         <td id="T_3ef9be8c_a0b6_11e8_9f13_144f8ae6cb7erow7_col1" class="data row7 col1" >2.26%</td>
#     </tr></tbody>
# </table>

# %%
#Bin the purchase_data data frame by age
#Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#Create a summary data frame to hold the results
#Optional: give the displayed data cleaner formatting
#Display the summary data frame


# Bin the Purchasing Data
purchase_data["Age Ranges"] = pd.cut(purchase_data["Age"], age_bins, labels=group_names)
# Run basic calculations
analysistot = purchase_data.groupby(["Age Ranges"]).sum()["Price"]
analysistot

analysisavg = purchase_data.groupby(["Age Ranges"]).mean()["Price"]
analysisavg

analysiscounts = purchase_data.groupby(["Age Ranges"]).count()["Price"]
analysiscounts
# Out:
# Age Ranges
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# >40       13
# Name: Price, dtype: int64

# %%
#Average Purchase Total per Person 


analysisperperson = analysistot / analysiscounts 
analysisperperson = analysisperperson.round(2)
analysisperperson
# Out:
# Age Ranges
# <10      3.35
# 10-14    2.96
# 15-19    3.04
# 20-24    3.05
# 25-29    2.90
# 30-34    2.93
# 35-39    3.60
# >40      2.94
# Name: Price, dtype: float64

# %%
#create DataFrame table
analysistable = pd.DataFrame({"Purchase Count": analysiscounts, "Average Purchase Price": analysisavg,
                             "Total Purchase Value": analysistot, "Average Purchase Per Person": analysisperperson})

#cleaner format
analysistable.style.format({"Average Purchase Price": "${:.2f}", "Total Purchase Value": "${:.2f}",
                           "Average Purchase Per Person": "${:.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7e" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Average Purchase Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#         <th class="col_heading level0 col3" >Average Purchase Per Person</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Age Ranges</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row0" class="row_heading level0 row0" ><10</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow0_col0" class="data row0 col0" >23</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow0_col1" class="data row0 col1" >$3.35</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow0_col2" class="data row0 col2" >$77.13</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow0_col3" class="data row0 col3" >$3.35</td>
#     </tr>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row1" class="row_heading level0 row1" >10-14</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow1_col0" class="data row1 col0" >28</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow1_col1" class="data row1 col1" >$2.96</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow1_col2" class="data row1 col2" >$82.78</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow1_col3" class="data row1 col3" >$2.96</td>
#     </tr>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row2" class="row_heading level0 row2" >15-19</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow2_col0" class="data row2 col0" >136</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow2_col1" class="data row2 col1" >$3.04</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow2_col2" class="data row2 col2" >$412.89</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow2_col3" class="data row2 col3" >$3.04</td>
#     </tr>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row3" class="row_heading level0 row3" >20-24</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow3_col0" class="data row3 col0" >365</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow3_col1" class="data row3 col1" >$3.05</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow3_col2" class="data row3 col2" >$1114.06</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow3_col3" class="data row3 col3" >$3.05</td>
#     </tr>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row4" class="row_heading level0 row4" >25-29</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow4_col0" class="data row4 col0" >101</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow4_col1" class="data row4 col1" >$2.90</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow4_col2" class="data row4 col2" >$293.00</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow4_col3" class="data row4 col3" >$2.90</td>
#     </tr>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row5" class="row_heading level0 row5" >30-34</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow5_col0" class="data row5 col0" >73</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow5_col1" class="data row5 col1" >$2.93</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow5_col2" class="data row5 col2" >$214.00</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow5_col3" class="data row5 col3" >$2.93</td>
#     </tr>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row6" class="row_heading level0 row6" >35-39</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow6_col0" class="data row6 col0" >41</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow6_col1" class="data row6 col1" >$3.60</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow6_col2" class="data row6 col2" >$147.67</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow6_col3" class="data row6 col3" >$3.60</td>
#     </tr>    <tr>
#         <th id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7elevel0_row7" class="row_heading level0 row7" >>40</th>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow7_col0" class="data row7 col0" >13</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow7_col1" class="data row7 col1" >$2.94</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow7_col2" class="data row7 col2" >$38.24</td>
#         <td id="T_84ff5da8_a0b6_11e8_825b_144f8ae6cb7erow7_col3" class="data row7 col3" >$2.94</td>
#     </tr></tbody>
# </table>

# %%
#Run basic calculations to obtain the results 
#Purchase Count
#Average Purchase Price
#Total Purchase Value

#Sort the total purchase value column in descending order
#Optional: give the displayed data cleaner formatting
#Display a preview of the summary data frame

topcount = purchase_data.groupby(["SN"]).count()["Price"]
topcount.head()
# Out:
# SN
# Adairialis76    1
# Adastirin33     1
# Aeda94          1
# Aela59          1
# Aelaria33       1
# Name: Price, dtype: int64

# %%
topavgcount = purchase_data.groupby(["SN"]).mean()["Price"]
topavgcount.head()
# Out:
# SN
# Adairialis76    2.28
# Adastirin33     4.48
# Aeda94          4.91
# Aela59          4.32
# Aelaria33       1.79
# Name: Price, dtype: float64

# %%
toptotalvalue = purchase_data.groupby(["SN"]).sum()["Price"]
toptotalvalue.head()
# Out:
# SN
# Adairialis76    2.28
# Adastirin33     4.48
# Aeda94          4.91
# Aela59          4.32
# Aelaria33       1.79
# Name: Price, dtype: float64

# %%
topspenders = pd.DataFrame({"Purchase Count": topcount, "Average Purchase Price": topavgcount,
                           "Total Purchase Value": toptotalvalue})

# %%
topspenders.style.format({"Average Purchase Price": "${:.2f}", "Total Purchase Value": "${:.2f}"})
topspenders.sort_values("Total Purchase Value", ascending=False).head()
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %%
#Most Popular Items
#Retrieve the Item ID, Item Name, and Item Price columns
#Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#Create a summary data frame to hold the results
#Sort the purchase count column in descending order
#Optional: give the displayed data cleaner formatting
#Display a preview of the summary data frame


#Purchase Count
#Item Price
#Total Purchase Value

mostpopcount = purchase_data.groupby(["Item ID", "Item Name"]).count()["Price"]
mostpopcount
# Out:
# Item ID  Item Name
# 0        Splinter                                         4
# 1        Crucifer                                         3
# 2        Verdict                                          6
# 3        Phantomlight                                     6
# 4        Bloodlord's Fetish                               5
# 5        Putrid Fan                                       4
# 6        Rusty Skull                                      2
# 7        Thorn, Satchel of Dark Souls                     7
# 8        Purgatory, Gem of Regret                         3
# 9        Thorn, Conqueror of the Corrupted                4
# 10       Sleepwalker                                      4
# 11       Brimstone                                        5
# 12       Dawne                                            6
# 13       Serenity                                         4
# 14       Possessed Core                                   2
# 15       Soul Infused Crystal                             5
# 16       Restored Bauble                                  4
# 17       Lazarus, Terror of the Earth                     4
# 18       Torchlight, Bond of Storms                       2
# 19       Pursuit, Cudgel of Necromancy                    8
# 20       Netherbane                                       5
# 21       Souleater                                        5
# 22       Amnesia                                          6
# 23       Crucifer                                         1
# 24       Warped Fetish                                    5
# 25       Hero Cane                                        6
# 26       Unholy Wand                                      2
# 27       Riddle, Tribute of Ended Dreams                  1
# 28       Flux, Destroyer of Due Diligence                 2
# 29       Chaos, Ender of the End                          5
#                                                          ..
# 154      Feral Katana                                     4
# 155      War-Forged Gold Deflector                        5
# 156      Soul-Forged Steel Shortsword                     5
# 157      Spada, Etcher of Hatred                          4
# 158      Darkheart, Butcher of the Champion               2
# 159      Oathbreaker, Spellblade of Trials                7
# 160      Azurewrath                                       6
# 161      Devine                                           5
# 162      Abyssal Shard                                    5
# 163      Thunderfury Scimitar                             5
# 164      Exiled Doomblade                                 7
# 165      Bone Crushing Silver Skewer                      4
# 166      Thirsty Iron Reaver                              3
# 167      Malice, Legacy of the Queen                      4
# 168      Sun Strike, Jaws of Twisted Visions              2
# 169      Interrogator, Blood Blade of the Queen           4
# 170      Shadowsteel                                      4
# 171      Scalpel                                          3
# 172      Blade of the Grave                               4
# 173      Stormfury Longsword                              2
# 174      Primitive Blade                                  4
# 175      Woeful Adamantite Claymore                       3
# 176      Relentless Iron Skewer                           2
# 177      Winterthorn, Defender of Shifting Worlds         2
# 178      Oathbreaker, Last Hope of the Breaking Storm    12
# 179      Wolf, Promise of the Moonwalker                  6
# 180      Stormcaller                                      1
# 181      Reaper's Toll                                    5
# 182      Toothpick                                        3
# 183      Dragon's Greatsword                              3
# Name: Price, Length: 183, dtype: int64

# %%
mostpoptot = purchase_data.groupby(["Item ID", "Item Name"]).sum()["Price"]
mostpoptot
# Out:
# Item ID  Item Name
# 0        Splinter                                         5.12
# 1        Crucifer                                         9.78
# 2        Verdict                                         14.88
# 3        Phantomlight                                    14.94
# 4        Bloodlord's Fetish                               8.50
# 5        Putrid Fan                                      16.32
# 6        Rusty Skull                                      7.40
# 7        Thorn, Satchel of Dark Souls                     9.31
# 8        Purgatory, Gem of Regret                        11.79
# 9        Thorn, Conqueror of the Corrupted               10.92
# 10       Sleepwalker                                      7.16
# 11       Brimstone                                       18.25
# 12       Dawne                                            6.12
# 13       Serenity                                         5.64
# 14       Possessed Core                                   5.22
# 15       Soul Infused Crystal                            14.80
# 16       Restored Bauble                                 14.20
# 17       Lazarus, Terror of the Earth                     6.80
# 18       Torchlight, Bond of Storms                       9.30
# 19       Pursuit, Cudgel of Necromancy                    8.16
# 20       Netherbane                                      16.35
# 21       Souleater                                        5.50
# 22       Amnesia                                         13.08
# 23       Crucifer                                         1.99
# 24       Warped Fetish                                   19.05
# 25       Hero Cane                                       26.10
# 26       Unholy Wand                                      2.24
# 27       Riddle, Tribute of Ended Dreams                  3.30
# 28       Flux, Destroyer of Due Diligence                 2.12
# 29       Chaos, Ender of the End                          9.90
#                                                          ...
# 154      Feral Katana                                    17.60
# 155      War-Forged Gold Deflector                        5.05
# 156      Soul-Forged Steel Shortsword                     8.85
# 157      Spada, Etcher of Hatred                         19.20
# 158      Darkheart, Butcher of the Champion               4.90
# 159      Oathbreaker, Spellblade of Trials               21.56
# 160      Azurewrath                                      26.40
# 161      Devine                                           8.80
# 162      Abyssal Shard                                   13.35
# 163      Thunderfury Scimitar                            17.25
# 164      Exiled Doomblade                                11.41
# 165      Bone Crushing Silver Skewer                     19.44
# 166      Thirsty Iron Reaver                              9.21
# 167      Malice, Legacy of the Queen                     14.44
# 168      Sun Strike, Jaws of Twisted Visions              2.96
# 169      Interrogator, Blood Blade of the Queen           8.72
# 170      Shadowsteel                                     15.88
# 171      Scalpel                                          5.37
# 172      Blade of the Grave                              12.56
# 173      Stormfury Longsword                              9.86
# 174      Primitive Blade                                 13.88
# 175      Woeful Adamantite Claymore                      13.44
# 176      Relentless Iron Skewer                           5.68
# 177      Winterthorn, Defender of Shifting Worlds         4.16
# 178      Oathbreaker, Last Hope of the Breaking Storm    50.76
# 179      Wolf, Promise of the Moonwalker                 26.88
# 180      Stormcaller                                      3.36
# 181      Reaper's Toll                                    8.30
# 182      Toothpick                                       12.09
# 183      Dragon's Greatsword                              3.27
# Name: Price, Length: 183, dtype: float64

# %%
mostpopprice = purchase_data.groupby(["Item ID", "Item Name"]).mean()["Price"]
mostpopprice
# Out:
# Item ID  Item Name
# 0        Splinter                                        1.28
# 1        Crucifer                                        3.26
# 2        Verdict                                         2.48
# 3        Phantomlight                                    2.49
# 4        Bloodlord's Fetish                              1.70
# 5        Putrid Fan                                      4.08
# 6        Rusty Skull                                     3.70
# 7        Thorn, Satchel of Dark Souls                    1.33
# 8        Purgatory, Gem of Regret                        3.93
# 9        Thorn, Conqueror of the Corrupted               2.73
# 10       Sleepwalker                                     1.79
# 11       Brimstone                                       3.65
# 12       Dawne                                           1.02
# 13       Serenity                                        1.41
# 14       Possessed Core                                  2.61
# 15       Soul Infused Crystal                            2.96
# 16       Restored Bauble                                 3.55
# 17       Lazarus, Terror of the Earth                    1.70
# 18       Torchlight, Bond of Storms                      4.65
# 19       Pursuit, Cudgel of Necromancy                   1.02
# 20       Netherbane                                      3.27
# 21       Souleater                                       1.10
# 22       Amnesia                                         2.18
# 23       Crucifer                                        1.99
# 24       Warped Fetish                                   3.81
# 25       Hero Cane                                       4.35
# 26       Unholy Wand                                     1.12
# 27       Riddle, Tribute of Ended Dreams                 3.30
# 28       Flux, Destroyer of Due Diligence                1.06
# 29       Chaos, Ender of the End                         1.98
#                                                          ...
# 154      Feral Katana                                    4.40
# 155      War-Forged Gold Deflector                       1.01
# 156      Soul-Forged Steel Shortsword                    1.77
# 157      Spada, Etcher of Hatred                         4.80
# 158      Darkheart, Butcher of the Champion              2.45
# 159      Oathbreaker, Spellblade of Trials               3.08
# 160      Azurewrath                                      4.40
# 161      Devine                                          1.76
# 162      Abyssal Shard                                   2.67
# 163      Thunderfury Scimitar                            3.45
# 164      Exiled Doomblade                                1.63
# 165      Bone Crushing Silver Skewer                     4.86
# 166      Thirsty Iron Reaver                             3.07
# 167      Malice, Legacy of the Queen                     3.61
# 168      Sun Strike, Jaws of Twisted Visions             1.48
# 169      Interrogator, Blood Blade of the Queen          2.18
# 170      Shadowsteel                                     3.97
# 171      Scalpel                                         1.79
# 172      Blade of the Grave                              3.14
# 173      Stormfury Longsword                             4.93
# 174      Primitive Blade                                 3.47
# 175      Woeful Adamantite Claymore                      4.48
# 176      Relentless Iron Skewer                          2.84
# 177      Winterthorn, Defender of Shifting Worlds        2.08
# 178      Oathbreaker, Last Hope of the Breaking Storm    4.23
# 179      Wolf, Promise of the Moonwalker                 4.48
# 180      Stormcaller                                     3.36
# 181      Reaper's Toll                                   1.66
# 182      Toothpick                                       4.03
# 183      Dragon's Greatsword                             1.09
# Name: Price, Length: 183, dtype: float64

# %%
mostpopdf = pd.DataFrame({"Purchase Count": mostpopcount, "Item Price": mostpopprice, "Total Purchase Value": mostpoptot})
mostpopdf.sort_values("Purchase Count", ascending=False).head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 145     Fiery Glass Crusader                                4.58
# 108     Extraction, Quickblade Of Trembling Hands           3.53
# 82      Nirvana                                             4.90
# 19      Pursuit, Cudgel of Necromancy                       1.02
#
#                                                       Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 145     Fiery Glass Crusader                                         41.22
# 108     Extraction, Quickblade Of Trembling Hands                    31.77
# 82      Nirvana                                                      44.10
# 19      Pursuit, Cudgel of Necromancy                                 8.16

# %%
mostpopdf.style.format({"Item Price": "${:.2f}",
                       "Total Purchase Value": "${:.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7e" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Item Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Item ID</th>
#         <th class="index_name level1" >Item Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row0" class="row_heading level0 row0" >0</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row0" class="row_heading level1 row0" >Splinter</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow0_col0" class="data row0 col0" >4</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow0_col1" class="data row0 col1" >$1.28</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow0_col2" class="data row0 col2" >$5.12</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row1" class="row_heading level0 row1" >1</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row1" class="row_heading level1 row1" >Crucifer</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow1_col0" class="data row1 col0" >3</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow1_col1" class="data row1 col1" >$3.26</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow1_col2" class="data row1 col2" >$9.78</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row2" class="row_heading level0 row2" >2</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row2" class="row_heading level1 row2" >Verdict</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow2_col0" class="data row2 col0" >6</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow2_col1" class="data row2 col1" >$2.48</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow2_col2" class="data row2 col2" >$14.88</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row3" class="row_heading level0 row3" >3</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row3" class="row_heading level1 row3" >Phantomlight</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow3_col0" class="data row3 col0" >6</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow3_col1" class="data row3 col1" >$2.49</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow3_col2" class="data row3 col2" >$14.94</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row4" class="row_heading level0 row4" >4</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row4" class="row_heading level1 row4" >Bloodlord's Fetish</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow4_col0" class="data row4 col0" >5</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow4_col1" class="data row4 col1" >$1.70</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow4_col2" class="data row4 col2" >$8.50</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row5" class="row_heading level0 row5" >5</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row5" class="row_heading level1 row5" >Putrid Fan</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow5_col0" class="data row5 col0" >4</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow5_col1" class="data row5 col1" >$4.08</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow5_col2" class="data row5 col2" >$16.32</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row6" class="row_heading level0 row6" >6</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row6" class="row_heading level1 row6" >Rusty Skull</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow6_col0" class="data row6 col0" >2</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow6_col1" class="data row6 col1" >$3.70</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow6_col2" class="data row6 col2" >$7.40</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row7" class="row_heading level0 row7" >7</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row7" class="row_heading level1 row7" >Thorn, Satchel of Dark Souls</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow7_col0" class="data row7 col0" >7</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow7_col1" class="data row7 col1" >$1.33</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow7_col2" class="data row7 col2" >$9.31</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row8" class="row_heading level0 row8" >8</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row8" class="row_heading level1 row8" >Purgatory, Gem of Regret</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow8_col0" class="data row8 col0" >3</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow8_col1" class="data row8 col1" >$3.93</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow8_col2" class="data row8 col2" >$11.79</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row9" class="row_heading level0 row9" >9</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row9" class="row_heading level1 row9" >Thorn, Conqueror of the Corrupted</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow9_col0" class="data row9 col0" >4</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow9_col1" class="data row9 col1" >$2.73</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow9_col2" class="data row9 col2" >$10.92</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row10" class="row_heading level0 row10" >10</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row10" class="row_heading level1 row10" >Sleepwalker</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow10_col0" class="data row10 col0" >4</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow10_col1" class="data row10 col1" >$1.79</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow10_col2" class="data row10 col2" >$7.16</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row11" class="row_heading level0 row11" >11</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row11" class="row_heading level1 row11" >Brimstone</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow11_col0" class="data row11 col0" >5</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow11_col1" class="data row11 col1" >$3.65</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow11_col2" class="data row11 col2" >$18.25</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row12" class="row_heading level0 row12" >12</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row12" class="row_heading level1 row12" >Dawne</th>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow12_col0" class="data row12 col0" >6</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow12_col1" class="data row12 col1" >$1.02</td>
#         <td id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7erow12_col2" class="data row12 col2" >$6.12</td>
#     </tr>    <tr>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel0_row13" class="row_heading level0 row13" >13</th>
#         <th id="T_a4fb7276_a0b8_11e8_9fcf_144f8ae6cb7elevel1_row13" class="row_heading le

# %%
#sort Total purchase value by descending
mostpopdf.sort_values("Total Purchase Value", ascending=False).head()
mostpopdf.style.format({"Item Price": "${:.2f}", "Total Purchase Value": "${:.2f}"})
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7e" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Purchase Count</th>
#         <th class="col_heading level0 col1" >Item Price</th>
#         <th class="col_heading level0 col2" >Total Purchase Value</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Item ID</th>
#         <th class="index_name level1" >Item Name</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row0" class="row_heading level0 row0" >0</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row0" class="row_heading level1 row0" >Splinter</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow0_col0" class="data row0 col0" >4</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow0_col1" class="data row0 col1" >$1.28</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow0_col2" class="data row0 col2" >$5.12</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row1" class="row_heading level0 row1" >1</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row1" class="row_heading level1 row1" >Crucifer</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow1_col0" class="data row1 col0" >3</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow1_col1" class="data row1 col1" >$3.26</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow1_col2" class="data row1 col2" >$9.78</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row2" class="row_heading level0 row2" >2</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row2" class="row_heading level1 row2" >Verdict</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow2_col0" class="data row2 col0" >6</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow2_col1" class="data row2 col1" >$2.48</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow2_col2" class="data row2 col2" >$14.88</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row3" class="row_heading level0 row3" >3</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row3" class="row_heading level1 row3" >Phantomlight</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow3_col0" class="data row3 col0" >6</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow3_col1" class="data row3 col1" >$2.49</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow3_col2" class="data row3 col2" >$14.94</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row4" class="row_heading level0 row4" >4</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row4" class="row_heading level1 row4" >Bloodlord's Fetish</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow4_col0" class="data row4 col0" >5</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow4_col1" class="data row4 col1" >$1.70</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow4_col2" class="data row4 col2" >$8.50</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row5" class="row_heading level0 row5" >5</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row5" class="row_heading level1 row5" >Putrid Fan</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow5_col0" class="data row5 col0" >4</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow5_col1" class="data row5 col1" >$4.08</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow5_col2" class="data row5 col2" >$16.32</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row6" class="row_heading level0 row6" >6</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row6" class="row_heading level1 row6" >Rusty Skull</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow6_col0" class="data row6 col0" >2</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow6_col1" class="data row6 col1" >$3.70</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow6_col2" class="data row6 col2" >$7.40</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row7" class="row_heading level0 row7" >7</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row7" class="row_heading level1 row7" >Thorn, Satchel of Dark Souls</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow7_col0" class="data row7 col0" >7</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow7_col1" class="data row7 col1" >$1.33</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow7_col2" class="data row7 col2" >$9.31</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row8" class="row_heading level0 row8" >8</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row8" class="row_heading level1 row8" >Purgatory, Gem of Regret</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow8_col0" class="data row8 col0" >3</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow8_col1" class="data row8 col1" >$3.93</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow8_col2" class="data row8 col2" >$11.79</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row9" class="row_heading level0 row9" >9</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row9" class="row_heading level1 row9" >Thorn, Conqueror of the Corrupted</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow9_col0" class="data row9 col0" >4</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow9_col1" class="data row9 col1" >$2.73</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow9_col2" class="data row9 col2" >$10.92</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row10" class="row_heading level0 row10" >10</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row10" class="row_heading level1 row10" >Sleepwalker</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow10_col0" class="data row10 col0" >4</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow10_col1" class="data row10 col1" >$1.79</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow10_col2" class="data row10 col2" >$7.16</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row11" class="row_heading level0 row11" >11</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row11" class="row_heading level1 row11" >Brimstone</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow11_col0" class="data row11 col0" >5</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow11_col1" class="data row11 col1" >$3.65</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow11_col2" class="data row11 col2" >$18.25</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row12" class="row_heading level0 row12" >12</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row12" class="row_heading level1 row12" >Dawne</th>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow12_col0" class="data row12 col0" >6</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow12_col1" class="data row12 col1" >$1.02</td>
#         <td id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7erow12_col2" class="data row12 col2" >$6.12</td>
#     </tr>    <tr>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel0_row13" class="row_heading level0 row13" >13</th>
#         <th id="T_b89bc8a2_a0b8_11e8_8189_144f8ae6cb7elevel1_row13" class="row_heading le

# %%
#3 Take Aways
#1. Based on the Most Popular, Thorn, Satchel of Dark Souls had the most in counts however Putrid Fan had the highest dollar
#   amount due to the cost of $4.08 vs $1.33. Putrid only needed 4 sales and it made almost half of what the highest count made.
#2. The age bracket of 20-24 doubled the amount of spend compared to the other age categories. Age group 40 and over had the lowest
#   amount of dollars spent. This is a segment that I would not recommend advertising to. I would look to grow the 15-19 segment.
#3  Males were the largest amount of purchasers an had the highest amount of dollars spent but were the lowest when it came to 
#   dollars spent per person. They followed females and the other classifications.
